# %%
print(sorted("abc"))
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# | Feature | `join()`        | `split()` |
# | ------- | --------------- | --------- |
# | Purpose | Combine         | Break     |
# | Input   | List of strings | String    |
# | Output  | String          | List      |
#
#
# split() → string → list ✂️
#
# join() → list → string 🔗

# %%
# 👉 String functions do not change original string

text = "hello"
text.upper()
print(text)
# ✔️ Because strings are immutable

# 🔸 To change value, store it

text = "hello"
text = text.upper()
print(text)
# Out:
# hello
# HELLO

# %%
print("---hi---".strip("-"))  # "hi"
"abc".strip("xyz")     # "abc" (no change)
# Out:
# hi
# 'abc'

# %%
",".join([])        # "" (empty string)
",".join(['a'])     # "a"
",".join(['a', 1])  # ❌ TypeError (must be str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 ",".join([])        # "" (empty string)
#       2 ",".join(['a'])     # "a"
# ----> 3 ",".join(['a', 1])  # ❌ TypeError (must be str)
#
# TypeError: sequence item 1: expected str instance, int found

# %%
sentence = "Python is easy to learn"

words = ["Python", "easy"]

if all(word in sentence for word in words):
    print("All words found")
# Out:
# All words found

# %%
range_count = text.count("Python", 20, 50) # Here, the method only searches from index 20 to 50. 
print(range_count)  # Output: 1
# It finds `"Python"` once within those bounds.
# Out:
# 0

# %% [markdown]
# #### string.replace(old, new, count)
#
# • old: The substring to replace.
#
# • new: The substring to replace it with.
#
# • count (optional): The maximum number of occurrences to replace. By default, replaces all occurrences.

# %%
text = "I love apples. Apples are my favorite fruit."
limited_text = text.replace("apples", "Oranges", 1)
print(limited_text)
# Output: I love Oranges. Apples are my favorite fruit.

text = "I love apples. Apples are my favorite fruit."
modified_text = text.replace("Apples", "Oranges")
print(modified_text)
# Output: I love apples. Oranges are my favorite fruit.
# Out:
# I love Oranges. Apples are my favorite fruit.
# I love apples. Oranges are my favorite fruit.

# %%
# Limiting the Number of Splits

text = "one two three four five"
limited_split = text.split(' ', 2)
print(limited_split)
# Out:
# ['one', 'two', 'three four five']

# %%
separator = "-"
original_string = "Hello"
result = separator.join(original_string)
print(result)
# Out:
# H-e-l-l-o

# %%
separator = " "
original_string = "World"
result = separator.join(original_string)
print(result)
# Out:
# W o r l d

# %%
my_string = "Python"
result = "".join(my_string)
print(result)
# Out:
# Python

# %%
sentence = "HELLO WORLD"  # Given string

# Use join() to insert '-' between each character
j = "-".join(sentence)

# Print the formatted sentence
print(j)
# Out:
# H-E-L-L-O- -W-O-R-L-D

# %%
text = "Welcome to Python programming!"
result = text.startswith("Python", 11, 17)
print(result)
# Out:
# True

# %%
file_name = "document.pdf"
result = file_name.startswith(("doc", "file"))
print(result)
# Out:
# True

# %%
item_code = "item-bookOfKnowledge"

starts_correct = item_code.startswith("item-")

# Extract the part after "item-"
rest = item_code[len("item-"):]
print(rest)

# Check if the rest is lowercase
is_lower = rest.islower()

print(starts_correct)
print(is_lower)
# Out:
# bookOfKnowledge
# True
# False

# %%
filename = "document.pdf"
print(filename.endswith((".pdf", ".docx", ".txt")))
# This checks if filename ends with any suffix in the tuple. Since filename ends with .pdf, the result is True.
# Out:
# True

# %%
number = "42"
padded_number = number.zfill(5)
print(padded_number) # Output: 00042
# "42" becomes "00042", ensuring a length of 5 by adding leading zeros.

negative_number = "-5"
padded_negative = negative_number.zfill(4)
print(padded_negative) # Output: -005 
# "-5" becomes "-005", ensuring a length of 4 by adding zeros in between '-' and '5'

long_number = "123456"
padded_long = long_number.zfill(3)
print(padded_long) # Output: 123456 
# Because "123456" is already longer than 3 characters, zfill() does not add zeros.
# Out:
# 00042
# -005
# 123456

# %%
text = "Hello"
centered_text = text.center(10)
print(f"'{centered_text}'")
# Output (spaces around Hello):
# '  Hello   '

text = "Hello"
centered_text = text.center(10, '*')
print(centered_text)
# Output: **Hello***

# The key point is that if the available space around the text is odd, the extra space goes to the right side. 
# Hence there were 2 *s to the left and 3 *s to the right of Hello
# Out:
# '  Hello   '
# **Hello***

# %%
my_string = "   Hello, World!"
cleaned_string = my_string.lstrip()
print(cleaned_string)  # Output: Hello, World!

# Removing specific leading characters
another_string = "***Hello, World!"
result = another_string.lstrip('*')
print(result)          # Output: Hello, World!
# Out:
# Hello, World!
# Hello, World!

# %%
# Removing trailing spaces
my_string = "Hello, World!   "
cleaned_string = my_string.rstrip()
print(cleaned_string)  # Output: Hello, World!

# Removing specific trailing characters
another_string = "Hello, World!!!"
result = another_string.rstrip('!')
print(result)          # Output: Hello, World
# Out:
# Hello, World!
# Hello, World

# %%
user_input = input()  # User enters: John Doe
print(user_input)
first_name, last_name = user_input.split()
print(first_name)
print(last_name)
# Out:
# raja beta
# raja
# beta

# %%
user_input = input()
first_name, age = user_input.split()
print("Hello, ", first_name, "! You are ", age, " years old.")

user_input = input()
first_name, age = user_input.split()
print("Hello, " + first_name + "! You are " + age + " years old.")

# | Feature | First Code (`,`)      | Second Code (`+`)    |
# | ------- | --------------------- | -------------------- |
# | Spacing | Adds automatic spaces | No automatic spaces  |
# | Control | Less control          | Full control         |
# | Ease    | Easier to write       | Slightly more typing |
# Out:
# Hello,  raja ! You are  5  years old.
# Hello, raja! You are 5 years old.

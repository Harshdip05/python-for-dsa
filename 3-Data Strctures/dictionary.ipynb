# %%
a = {1, 2, 3}
b = {3, 4, 5}

result = a.union(b)
print(result)
# Out:
# {1, 2, 3, 4, 5}

# %%
a = {1, 2, 3}
b = {3, 4, 5}

result = a | b
print(result)
# Out:
# {1, 2, 3, 4, 5}

# %%
s = {1, 2, 3,4,5,6}
s.pop()

# 👉 Removes random element 😄
# Out:
# 1

# %%
print(s)
# Out:
# {2, 3, 4, 5, 6}

# %% [markdown]
# | Feature          | `union()` | `update()` |
# | ---------------- | --------- | ---------- |
# | Returns new set  | ✅ Yes     | ❌ No       |
# | Changes original | ❌ No      | ✅ Yes      |

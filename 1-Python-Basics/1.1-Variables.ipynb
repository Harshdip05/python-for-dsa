# %% [markdown]
# ### Variables
# Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program. In Python, variables are created when you assign a value to them, and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assign a value to a variable.

# %%
a = 100

# %%
# declaring and asssigning variables
age =  20
height = 6.5
name = "Raj"
is_student = True   # snake_case

# printing variables
print("age",age)
print("height:",height)
print("name:",name)
# Out:
# age 20
# height: 6.5
# name: Raj

# %%
## Naming Conventions
# Variable names should be descriptive
# They must start with a letter or an '_' and contains letter,numbers and underscores
# variables names case sensitive

#valid variable names

first_name = "Harsh"
_id = 5

# %%
## invalid variable name
2age = 30
first-name ="Harsh"  #The - (hyphen) is treated as the minus operator, not as part of a variable name
$name = "Harsh"
n@me = "Harsh"
first name = "Harsh"
if = "harsh"
# Out:
#   Cell In[5], line 2
#     2age = 30
#     ^
# SyntaxError: invalid decimal literal

# %%
## case sensitivity: Python is case sensitive

name = "Harsh"
Name = "Nandre"
print(name)
print(Name)
# Out:
# Harsh
# Nandre

# %%
## variable types
# Python is dynamically typed,type of a variable is determined at runtime

age=25 #int
height=6.1 #float
name="harsh" #str
is_student=True #bool

print(type(name))
# Out:
# <class 'str'>

# %%
# type checking
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
## Types of Type Conversion
# Implicit Type Conversion
# Explicit Type Conversion (Type Casting)

a = 10 
b = 2.5
c = a+b
print(a,type(a))
print(b,type(b))
print(c,type(c))

# int → converted to float
# Python prevents data loss
# Result becomes float
# Out:
# 10 <class 'int'>
# 2.5 <class 'float'>
# 12.5 <class 'float'>

# %%
# Python is strongly typed.
# implicit convertion will not happen here

TypeError: can only concatenate str (not "int") to str
a = "10"
b = 5
print(a + b)

# %%
a = 10 
print(a,type(a))
b = str(a)
print(b,type(b))
print(type(a))
# Out:
# 10 <class 'int'>
# 10 <class 'str'>
# <class 'int'>

# %%
a = "10"
b = 5

result = int(a) + b
print(result)
# Out:
# 15

# %%
b = 5
print(bool(b))
print(float(b))
print(list(b))
# Out:
# True
# 5.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       2 print(bool(b))
#       3 print(float(b))
# ----> 4 print(list(b))
#
# TypeError: 'int' object is not iterable

# %%
b = "abc"
print(bool(b))
# print(float(b))
print(list(b))
print(set(b))
print(tuple(b))
# Out:
# True
# ['a', 'b', 'c']
# {'a', 'b', 'c'}
# ('a', 'b', 'c')

# %%
int("Harsh")
# Because "Harsh" is not numeric.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 int("Harsh")
#       2 # Because "Harsh" is not numeric.
#
# ValueError: invalid literal for int() with base 10: 'Harsh'

# %%
## Dynamic typing
# python allows type of variable to change as program executes

var = 10
print(var,type(var))

var = "Hello"
print(var,type(var))

var = 1.3
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 1.3 <class 'float'>

# %%
## input
i = input()
print(i)

print(input())

age = int(input("what is your age?"))
print(age)
# Out:
# 123
# 123
# 123

# %%
## simple calculator
num1 = float(input("enter num1: "))
num2 = float(input("enter num1: "))

sum = num1+num2
sub = num1-num2
div1 = num1/num2
div2 = num2/num1
multi = num1*num2
mod = num1%num2
floor = num1//num2
expo = num1**num2

print("addition",sum)
print("subtraction",sub)
print("division",div1)  # quotient
print(div2)
print("multiplication",multi)
print("modulo",mod)
print("floor",floor)
print("expo",expo)
# Out:
# addition 8.1
# subtraction -3.3000000000000003
# division 0.42105263157894735
# 2.375
# multiplication 13.68
# modulo 2.4
# floor 0.0
# expo 146.96166977052837

# %% [markdown]
# ### Conclusion:
# Variables are essential in Python programming for storing and manipulating data. Understanding how to declare, assign, and use variables effectively is crucial for writing functional and efficient code. Following proper naming conventions and understanding variable types will help in maintaining readability and consistency in your code.

# %%
class Node:
    '''
    this is a node in singly linked list

    Attributes:
                data
                next
    '''
    def __init__(self,data):
        self.data = data 
        self.next = None


class LinkedList:
    
    def __init__(self,)

# %%
# 10 --> 20 --> 30

node1 = Node(10)
node2 = Node(20)
node3 = Node(30)

node1.next = node2
node2.next = node3

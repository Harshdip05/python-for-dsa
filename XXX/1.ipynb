# %%
# Out:
# Hello World

# %%
class Student():
    college = "NCER"
    def __init__(self):
        print("sdads")

s1 = Student()
# print(s1)
print(s1.college)
s2 = Student()
# print(s2)
# Out:
# sdads
# NCER
# sdads

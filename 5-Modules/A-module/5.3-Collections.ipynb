# %%
import collections

from collections import Counter , defaultdict , deque , namedtuple , OrderedDict

print(dir(collections))   ##  displays a list of all valid attributes and methods within the collections module
# Out:
# ['ChainMap', 'Counter', 'OrderedDict', 'UserDict', 'UserList', 'UserString', '_Link', '_OrderedDictItemsView', '_OrderedDictKeysView', '_OrderedDictValuesView', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_chain', '_collections_abc', '_count_elements', '_deque_iterator', '_eq', '_iskeyword', '_itemgetter', '_proxy', '_recursive_repr', '_repeat', '_starmap', '_sys', '_tuplegetter', 'abc', 'defaultdict', 'deque', 'namedtuple']

# %%
from collections import Counter 

data = ["a","b","a","c","d","e","f","e","e","e","e","f","z","a"]
print(data)

count = Counter(data)
print(count)

print(count["a"])
print(count["e"])
# print(count[a])

print(count.most_common())   # returns all elements from highest frequency to lowest
print(count.most_common(1))
print(count.most_common(2))  ## top 2 most common

count.update([1,2])
print(count)
print(data)

count.subtract([2])
print(count)
print(data)

print(dict(count))   ## convert Counter to dictionary

for key,value in count.items():   ## loop through Counter
    print(key,value)
# Out:
# ['a', 'b', 'a', 'c', 'd', 'e', 'f', 'e', 'e', 'e', 'e', 'f', 'z', 'a']
# Counter({'e': 5, 'a': 3, 'f': 2, 'b': 1, 'c': 1, 'd': 1, 'z': 1})
# 3
# 5
# [('e', 5), ('a', 3), ('f', 2), ('b', 1), ('c', 1), ('d', 1), ('z', 1)]
# [('e', 5)]
# [('e', 5), ('a', 3)]
# Counter({'e': 5, 'a': 3, 'f': 2, 'b': 1, 'c': 1, 'd': 1, 'z': 1, 1: 1, 2: 1})
# ['a', 'b', 'a', 'c', 'd', 'e', 'f', 'e', 'e', 'e', 'e', 'f', 'z', 'a']
# Counter({'e': 5, 'a': 3, 'f': 2, 'b': 1, 'c': 1, 'd': 1, 'z': 1, 1: 1, 2: 0})
# ['a', 'b', 'a', 'c', 'd', 'e', 'f', 'e', 'e', 'e', 'e', 'f', 'z', 'a']
# {'a': 3, 'b': 1, 'c': 1, 'd': 1, 'e': 5, 'f': 2, 'z': 1, 1: 1, 2: 0}
# a 3
# b 1
# c 1
# d 1
# e 5
# f 2
# z 1
# 1 1
# 2 0

# %%
from collections import Counter

numbers = [1, 2, 2, 3, 3, 3, 4]

count = Counter(numbers)

print(count)
print(count["1"])   ## "1" is a string, not an integer
print(count[1])     ## 1 is an integer, and it exists in the Counter

print(count[6])
# If a key does not exist, it returns 0 instead of an error.
# In normal dictionaries this would cause KeyError.
# Out:
# Counter({3: 3, 2: 2, 1: 1, 4: 1})
# 0
# 1
# 0

# %%
## word frequency(count words in text)

from collections import Counter

sentence = "python is easy and python is powerful"

words = Counter(sentence)
print(words)

words2 = Counter(sentence.split())
print(words2)
# Out:
# Counter({' ': 6, 'p': 3, 'y': 3, 'o': 3, 'n': 3, 's': 3, 't': 2, 'h': 2, 'i': 2, 'e': 2, 'a': 2, 'd': 1, 'w': 1, 'r': 1, 'f': 1, 'u': 1, 'l': 1})
# Counter({'python': 2, 'is': 2, 'easy': 1, 'and': 1, 'powerful': 1})

# %%
from collections import Counter

text = "banana"
c = Counter(text)
print(c)
print(c.elements)
print(c.elements())
print((list(c.elements())))
# Out:
# Counter({'a': 3, 'n': 2, 'b': 1})
# <bound method Counter.elements of Counter({'a': 3, 'n': 2, 'b': 1})>
# ...
# ['b', 'a', 'a', 'a', 'n', 'n']

# %%
## voting system(find winner)

from collections import Counter

votes = ["A","B","C","A","A","A","C","D","E","E","E"]
result = Counter(votes)
print(result)

winner = result.most_common(1)
print(winner)
# Out:
# Counter({'A': 4, 'E': 3, 'C': 2, 'B': 1, 'D': 1})
# [('A', 4)]

# %%
## data analysis(find most common data)

from collections import Counter

ages = [20,21,18,18,20,20,20,20,20,19,20,21,22,21,21,20]
c = Counter(ages)
print(c)

print(c.most_common(1)) ## age 20 appears 8 times
# Out:
# Counter({20: 8, 21: 4, 18: 2, 19: 1, 22: 1})
# [(20, 8)]

# %%
## log analysis(count system counts)

from collections import Counter

logs = ["INFO","INFO","ERROR","ERROR","INFO","WARNING"]
log_count = Counter(logs)
print(log_count)

print(log_count.most_common(1))
# Out:
# Counter({'INFO': 3, 'ERROR': 2, 'WARNING': 1})
# [('INFO', 3)]

# %%
from collections import Counter
data = [1,2,2,3,3,3]
c = Counter(data)
print(c)


# without counter
data = [1,2,2,3,3,3]
count = {}
for item in data:
    if item in count:      # Does this item already exist as a key in the dictionary count?
        count[item] += 1
    else:
        count[item] = 1
print(count)
# Out:
# Counter({3: 3, 2: 2, 1: 1})
# {1: 1, 2: 2, 3: 3}

# %%
# arithmetic with counters

c1 = Counter([1,2,2])
c2 = Counter([2,3])
print(c1+c2)
print(c1-c2)
print(c2-c1)
# Out:
# Counter({2: 3, 1: 1, 3: 1})
# Counter({1: 1, 2: 1})
# Counter({3: 1})

# %% [markdown]
# | Feature         | Normal Dictionary 🧾 | Counter ⚡                  |
# | --------------- | -------------------- | -------------------------- |
# | Counting        | Manual loop          | Automatic                  |
# | Missing key     | Error                | Returns 0                  |
# | Most common     | Need sorting         | Built-in (`most_common()`) |
# | Update counts   | Manual               | `.update()`                |
# | Math operations | Not easy             | Supported (`+`, `-`, etc.) |

# %%
# min no of balloon
from collections import Counter

text = "balloon"
count = Counter(text)
print(count)
print(min(count["b"],count["a"],count["l"]//2,count["o"]//2,count["n"]))



text = "balloon"
b = a = l = o = n = 0
for ch in text:
    if ch == 'b':
        b += 1
    elif ch == 'a':
        a += 1
    elif ch == 'l':
        l += 1
    elif ch == 'o':
        o += 1
    elif ch == 'n':
        n += 1
print(min(b,a,l//2,o//2,n))
# Out:
# Counter({'l': 2, 'o': 2, 'b': 1, 'a': 1, 'n': 1})
# 1
# 1

# %%
from collections import Counter

text = "aaaaaabbbc"
count = Counter(text)
print(count)
print(count["a"])
print(count["z"])
print(list(count.elements()))
print(c.most_common())              ## sort elements by frequency
print(c.most_common()[-1])
print(c.most_common(1))
print(c.most_common(1)[0][0]) ## extract only element


print()


duplicates = [x for x in count if count[x]>1]
print(duplicates)

print()

unique = [x for x in count if count[x]==1]      ## count[x] == k (find element appearing k times)
print(unique)
# Out:
# Counter({'a': 6, 'b': 3, 'c': 1})
# 6
# 0
# ['a', 'a', 'a', 'a', 'a', 'a', 'b', 'b', 'b', 'c']
# [('d', 3), ('a', 2), ('s', 1), ('e', 1), ('x', 1), ('y', 1), ('z', 1)]
# ('z', 1)
# [('d', 3)]
# d
#
# ['a', 'b']
#
# ['c']

# %%
# check anagrams
# two strings have same character frequency

s1 = "listen"
s2 = "silent"

print(Counter(s1)==Counter(s2))
# Out:
# True

# %%
# first non repeating character

s = "dadasdexyz"

c = Counter(s)

for i in range(len(s)):
    if c[s[i]] == 1:
        print(s[i])  ## if only i then get index
        break

for ch in s:
    if c[ch] == 1:
        print(ch)
        break
# Out:
# s
# s

# %%
votes = ["A","B","C","A","A","A","C","D","E","E","E"]
result = Counter(votes)
print(result)

least_no = min(result["A"],result["B"],result["C"],result["D"],result["E"])
print(least_no)

least_element = min(result,key=result.get)
print(least_element)

min_freq = min(c.values())
result2 = [k for k in result if result[k] == min_freq]
print(result2)

count_duplicates = sum(1 for x in result if result[x]>1)
print(count_duplicates)
# Out:
# Counter({'A': 4, 'E': 3, 'C': 2, 'B': 1, 'D': 1})
# 1
# B
# ['B', 'D']
# 3

# %%
ransomNote = "aa"
magazine = "aab"
s1 = Counter(ransomNote)
s2 = Counter(magazine)
print(s1)
print(s2)

print(s1<=s2)
# Out:
# Counter({'a': 2})
# Counter({'a': 2, 'b': 1})
# True

# %%
# pangram

from collections import Counter

str1 = "TheQuickBrownFoxJumpsOverTheLazyDog".lower()
print(len(str1))

n = len(str1)

count  = Counter(str1)
print(count)

duplicates = [x for x in count if count[x]>=1]
print(duplicates)
duplicates = list(count.keys())
print(duplicates)

print(set(duplicates))

print(len(set(duplicates)))
# Out:
# 35
# Counter({'o': 4, 'e': 3, 't': 2, 'h': 2, 'u': 2, 'r': 2, 'q': 1, 'i': 1, 'c': 1, 'k': 1, 'b': 1, 'w': 1, 'n': 1, 'f': 1, 'x': 1, 'j': 1, 'm': 1, 'p': 1, 's': 1, 'v': 1, 'l': 1, 'a': 1, 'z': 1, 'y': 1, 'd': 1, 'g': 1})
# ['t', 'h', 'e', 'q', 'u', 'i', 'c', 'k', 'b', 'r', 'o', 'w', 'n', 'f', 'x', 'j', 'm', 'p', 's', 'v', 'l', 'a', 'z', 'y', 'd', 'g']
# ['t', 'h', 'e', 'q', 'u', 'i', 'c', 'k', 'b', 'r', 'o', 'w', 'n', 'f', 'x', 'j', 'm', 'p', 's', 'v', 'l', 'a', 'z', 'y', 'd', 'g']
# {'r', 'n', 'l', 'd', 'f', 'p', 'v', 'u', 'm', 'b', 'h', 'q', 'i', 'o', 'e', 'j', 'a', 'z', 'c', 'k', 'g', 's', 'w', 't', 'y', 'x'}
# 26

# %%
from collections import Counter

s1 ="BABBONATALE"
s2 = "FATHERCHRISTMAS"
str12 = "BABCHRISTMASBONATALLEFATHER"

c1 = Counter(s1)
print(c1)
c2 = Counter(s2)
print(c2)
c12 = Counter(str12)
print(c12)

print(c1+c2==c12)
# Out:
# Counter({'B': 3, 'A': 3, 'O': 1, 'N': 1, 'T': 1, 'L': 1, 'E': 1})
# Counter({'A': 2, 'T': 2, 'H': 2, 'R': 2, 'S': 2, 'F': 1, 'E': 1, 'C': 1, 'I': 1, 'M': 1})
# Counter({'A': 5, 'B': 3, 'T': 3, 'H': 2, 'R': 2, 'S': 2, 'L': 2, 'E': 2, 'C': 1, 'I': 1, 'M': 1, 'O': 1, 'N': 1, 'F': 1})
# False

# %%
s1 ="BABBONATALE"
s2 = "FATHERCHRISTMAS"
str12 = "BABCHRISTMASBONATALLEFATHER"

ss1 = set(s1)
print(ss1)

ss2 = set(s2)
print(ss2)

sstr12 = set(str12)
print(sstr12)

# print(ss1+ss2 == sstr12)
# Out:
# {'L', 'O', 'E', 'B', 'T', 'N', 'A'}
# {'R', 'I', 'E', 'T', 'C', 'S', 'F', 'M', 'H', 'A'}
# {'L', 'R', 'I', 'O', 'B', 'T', 'C', 'S', 'N', 'E', 'F', 'M', 'H', 'A'}

# %% [markdown]
# You’re aiming for “all Counter problems,” but that’s not realistic—there are **hundreds** of LeetCode problems where collections module Counter can be used.
#
# What actually *makes you strong* is knowing the **patterns** and the **most important problems** in each pattern. I’ll give you a **complete roadmap** (this is what top candidates actually use).
#
# ---
#
# # 🧠 1. Frequency Counting Problems (FOUNDATION)
#
# 👉 Direct use of `Counter`
#
# ### Must-do:
#
# * **LeetCode 242** – Valid Anagram
# * **LeetCode 383** – Ransom Note
# * **LeetCode 387** – First Unique Character
# * **LeetCode 389** – Find the Difference
# * **LeetCode 169** – Majority Element
#
# ### Pattern:
#
# ```python
# Counter(a) == Counter(b)
# ```
#
# ✔ Used when comparing frequencies
#
# ---
#
# # 🔥 2. Top K Frequent (VERY IMPORTANT)
#
# 👉 Uses `most_common()`
#
# ### Must-do:
#
# * **LeetCode 347** – Top K Frequent Elements
# * **LeetCode 692** – Top K Frequent Words
#
# ### Pattern:
#
# ```python
# Counter(nums).most_common(k)
# ```
#
# ✔ Extremely common in interviews
#
# ---
#
# # 🧩 3. Anagram + Sliding Window
#
# 👉 Counter + window comparison
#
# ### Must-do:
#
# * **LeetCode 438** – Find All Anagrams in a String
# * **LeetCode 567** – Permutation in String
#
# ### Pattern:
#
# ```python
# window == target_counter
# ```
#
# ✔ Combine Counter + sliding window
#
# ---
#
# # 🔁 4. Multiset / Intersection Problems
#
# 👉 Uses Counter math (`&`, `|`)
#
# ### Must-do:
#
# * **LeetCode 350** – Intersection of Two Arrays II
# * **LeetCode 349** – Intersection of Two Arrays
#
# ### Pattern:
#
# ```python
# c1 & c2
# list((c1 & c2).elements())
# ```
#
# ---
#
# # 🧮 5. Counting + Greedy
#
# 👉 Counter helps choose most frequent items
#
# ### Must-do:
#
# * **LeetCode 451** – Sort Characters By Frequency
# * **LeetCode 621** – Task Scheduler
# * **LeetCode 767** – Reorganize String
#
# ---
#
# # 🧠 6. Advanced Counting Problems
#
# 👉 Trickier logic using Counter
#
# ### Must-do:
#
# * **LeetCode 560** – Subarray Sum Equals K *(Counter-like hashmap)*
# * **LeetCode 904** – Fruit Into Baskets
# * **LeetCode 1002** – Find Common Characters
# * **LeetCode 1207** – Unique Number of Occurrences
#
# ---
#
# # 🧪 7. Hard-Level Counter Problems
#
# 👉 These test real mastery
#
# ### Must-do:
#
# * **LeetCode 76** – Minimum Window Substring
# * **LeetCode 30** – Substring with Concatenation of All Words
# * **LeetCode 895** – Maximum Frequency Stack
# * **LeetCode 128** – Longest Consecutive Sequence *(indirect)*
#
# ---
#
# # 📊 8. Less Obvious (Hidden Counter Use)
#
# 👉 These don’t say “count” directly
#
# ### Must-do:
#
# * **LeetCode 3** – Longest Substring Without Repeating Characters
# * **LeetCode 49** – Group Anagrams
# * **LeetCode 451** – Frequency Sort
#
# ---
#
# # 🧠 MASTER PATTERNS (THIS IS WHAT MATTERS)
#
# Forget memorizing problems—learn these:
#
# ---
#
# ## ✅ Pattern 1: Frequency Compare
#
# ```python
# Counter(s) == Counter(t)
# ```
#
# ---
#
# ## ✅ Pattern 2: Top K
#
# ```python
# Counter(nums).most_common(k)
# ```
#
# ---
#
# ## ✅ Pattern 3: Sliding Window
#
# ```python
# window == target
# ```
#
# ---
#
# ## ✅ Pattern 4: Multiset Math
#
# ```python
# c1 & c2
# c1 | c2
# ```
#
# ---
#
# ## ✅ Pattern 5: Greedy with Frequency
#
# ```python
# max(Counter(values))
# ```
#
# ---
#
# # 🚀 How to Actually Master Counter
#
# Don’t try to solve everything. Do this instead:
#
# ### Step 1:
#
# Solve these 10:
#
# * 242, 347, 438, 567, 350
# * 169, 451, 621, 76, 49
#
# ### Step 2:
#
# Understand patterns (not code)
#
# ### Step 3:
#
# Practice variations
#
# ---
#
# # ⚠️ Reality Check
#
# If you:
#
# * memorize → you’ll forget
# * understand patterns → you’ll solve new problems
#
# ---
#
# # 🧠 Final Insight
#
# > Counter is not the goal.
# > **Pattern recognition is the goal.**
#
# ---
#
# If you want, I can:
#
# * 🔥 Give you a **day-wise roadmap (like 7 days to master Counter)**
# * 💯 Solve **one HARD problem step-by-step (like Minimum Window Substring)**
# * 🧠 Give **tricky interview questions where Counter is hidden**

# %% [markdown]
# Good—this is the right way to learn. A focused 7-day plan will take you from “I know Counter” to “I can use it in interviews without thinking.”
#
# Here’s a **tight, practical 7-day roadmap** using collections module Counter.
#
# ---
#
# # 🚀 Day 1 — Foundations (Must be crystal clear)
#
# ### 🎯 Goal:
#
# Understand what Counter *is* and how it behaves
#
# ### Learn:
#
# * Creating Counter from list, string, dict
# * Accessing values
# * Missing keys → 0
# * `elements()`, `most_common()`
#
# ### Practice:
#
# ```python
# Counter("banana")
# Counter([1,2,2,3])
# ```
#
# ### Problems:
#
# * LeetCode 389 – Find the Difference
# * LeetCode 387 – First Unique Character
#
# 👉 Focus: **counting + basic lookup**
#
# ---
#
# # 🔥 Day 2 — Frequency Comparison (Core Pattern)
#
# ### 🎯 Goal:
#
# Compare two datasets using Counter
#
# ### Learn:
#
# ```python
# Counter(a) == Counter(b)
# ```
#
# ### Problems:
#
# * LeetCode 242 – Valid Anagram
# * LeetCode 383 – Ransom Note
#
# ### Insight:
#
# > If two things have same counts → they are equivalent
#
# ---
#
# # 🧠 Day 3 — Top K Pattern
#
# ### 🎯 Goal:
#
# Master `most_common()`
#
# ### Learn:
#
# ```python
# Counter(nums).most_common(k)
# ```
#
# ### Problems:
#
# * LeetCode 347 – Top K Frequent Elements
# * LeetCode 692 – Top K Frequent Words
#
# ### Extra:
#
# Try solving without `most_common()` (heap approach)
#
# ---
#
# # 🧩 Day 4 — Sliding Window + Counter
#
# ### 🎯 Goal:
#
# This is where beginners struggle → you won’t
#
# ### Learn:
#
# * Maintain a window Counter
# * Compare with target Counter
#
# ### Problems:
#
# * LeetCode 438 – Find All Anagrams
# * LeetCode 567 – Permutation in String
#
# ### Pattern:
#
# ```python
# if window == target:
#     # match found
# ```
#
# ---
#
# # 🔁 Day 5 — Counter Math (Underrated but Powerful)
#
# ### 🎯 Goal:
#
# Understand multiset operations
#
# ### Learn:
#
# ```python
# c1 + c2
# c1 - c2
# c1 & c2
# c1 | c2
# ```
#
# ### Problems:
#
# * LeetCode 350 – Intersection of Two Arrays II
# * LeetCode 1002 – Find Common Characters
#
# ### Insight:
#
# > Counter = math on frequencies
#
# ---
#
# # 🧮 Day 6 — Greedy + Frequency
#
# ### 🎯 Goal:
#
# Use Counter to make decisions
#
# ### Problems:
#
# * LeetCode 451 – Sort Characters by Frequency
# * LeetCode 621 – Task Scheduler
# * LeetCode 767 – Reorganize String
#
# ### Insight:
#
# > Highest frequency often drives the solution
#
# ---
#
# # 🧠 Day 7 — Hard Problems (Real Mastery)
#
# ### 🎯 Goal:
#
# Handle complex logic with Counter
#
# ### Problems:
#
# * LeetCode 76 – Minimum Window Substring
# * LeetCode 30 – Substring with Concatenation of All Words
#
# ### Focus:
#
# * Combining:
#
#   * Counter
#   * Sliding window
#   * Conditions
#
# ---
#
# # 📊 Daily Structure (IMPORTANT)
#
# Each day:
#
# ### ⏱️ 1 hour:
#
# * Learn concept
#
# ### ⏱️ 1–2 hours:
#
# * Solve 2–3 problems
#
# ### ⏱️ 30 min:
#
# * Review mistakes
#
# ---
#
# # 🧠 Golden Rules (Read Daily)
#
# 1. If you see **frequency → think Counter**
# 2. If you see **top K → think most_common**
# 3. If you see **substring + permutation → sliding window + Counter**
# 4. If you see **intersection → use `&`**
#
# ---
#
# # 🚀 After 7 Days You’ll Be Able To:
#
# ✔ Recognize Counter problems instantly
# ✔ Solve medium problems quickly
# ✔ Handle tricky edge cases
# ✔ Use Counter like a pro
#
# ---
#
# # ⚠️ One Honest Truth
#
# Most people fail because:
#
# * They *read* solutions
# * Instead of *writing code themselves*
#
# 👉 You must code every problem.
#
# ---
#
# If you want next step, I can:
#
# * 🔥 Turn this into a **daily schedule with exact questions + solutions**
# * 💯 Give you **mock interview questions using Counter**
# * 🧠 Walk you through **Minimum Window Substring step-by-step (hard level)**

# %% [markdown]
# ##### Standard Library Overview
# Python's Standard Library is a vast collection of modules and packages that come bundled with Python, providing a wide range of functionalities out of the box. Here's an overview of some of the most commonly used modules and packages in the Python Standard Library.

# %%
import array
arr = array.array("i",[1,2,3,4,5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
## random 
import random
print(random.randint(1,10))
print(random.choice(["a","b","c"]))
# Out:
# 10
# b

# %%
## os - file and directory access

import os 
print(os.getcwd)
print(os.getcwd())
# Out:
# <built-in function getcwd>
# d:\python-for-dsa\5-Modules

# %%
os.mkdir("test_dir")

# %%
# high level operation on files or collection of files

import shutil
shutil.copyfile("source.txt","destination.txt")
# Out:
# 'destination.txt'

# %%
## data serialization
# converting dict to json or converting dataframe

import json

data = {
    'name':'raj',
    'age':10,
}
print(type(data))

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# <class 'dict'>
# {"name": "raj", "age": 10}
# <class 'str'>
# {'name': 'raj', 'age': 10}
# <class 'dict'>

# %%
# csv

import csv

with open('example.csv',mode='w',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["name",'age'])
    writer.writerow(['raj',10])

with open('example.csv',mode='r') as file:
    reader = csv.reader(file)
    for  row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['raj', '10']

# %%
# datetime

from datetime import datetime,timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-03-03 14:44:52.406531
# 2026-03-02 14:44:52.406531

# %%
# time 

import time

print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1772529367.8132484
# 1772529369.814029

# %%
## regular expression

import re

pattern = r'\d+'
text = 'There are 123 apples'
match = re.search(pattern,text)
print(match)
print(match.group())
# Out:
# <re.Match object; span=(10, 13), match='123'>
# 123

# %%
import re

pattern = r'\d+'
text = 'There are 123 apples  321'
match = re.search(pattern,text)
print(match)
print(match.group())
# Out:
# <re.Match object; span=(10, 13), match='123'>
# 123

# %% [markdown]
# #### Conclusion
# Python's Standard Library is extensive and provides tools for almost any task you can think of, from file handling to web services, from data serialization to concurrent execution. Familiarizing yourself with the modules and packages available in the Standard Library can significantly enhance your ability to write efficient and effective Python programs.

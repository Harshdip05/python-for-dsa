# %% [markdown]
# | Method  | Work          | Time       |
# | ------- | ------------- | ---------- |
# | append  | Add end       | O(1)       |
# | insert  | Add middle    | O(n)       |
# | extend  | Add many      | O(k)       |
# | pop     | Remove index  | O(1)/O(n)  |
# | remove  | Remove value  | O(n)       |
# | index   | Find position | O(n)       |
# | count   | Count value   | O(n)       |
# | sort    | Sort          | O(n log n) |
# | reverse | Reverse       | O(n)       |
# | copy    | Copy          | O(n)       |
# | clear   | Empty list    | O(n)       |
# | len     | Size          | O(1)       |

# %%
arr = list(map(int, input().split()))
print(arr)
# Out:
# [1]

# %%
import array
arr = array.array('i', [1, 2, 3, 4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
from array import array

arr2 = array('f', [1.1, 2.2, 3.3])
print(arr2)
# Out:
# array('f', [1.100000023841858, 2.200000047683716, 3.299999952316284])

# %%
def linear_search(arr,t):
    for index in range(len(arr)):
        if arr[index] == t:
            return index
    return -1        

my_list = [10,20,30,40,50,60]
target = 50
result = linear_search(my_list,target)
print(result)
# Out:
# 4

# %%
def linear_search(arr,t):
    for index in range(len(arr)):
        if arr[index] == t:
            return index
    return -1        

my_list = ["a","b","c","d","e"]
target = "a"
result = linear_search(my_list,target)
print(result)
# Out:
# 0

# %% [markdown]
# we talk of worst case so: O(n)
# time complexity is propertional to loop
#
# O(1) = best case

# %%
def largest_number(arr):
    largest = arr[0]

    for num in arr:
        if num>largest:
            largest = num
        
    return largest     

arr1 = [3, 7, 2, 9, 5]
print(largest_number(arr1))
# Out:
# 9

# %%
def reverse_slicing(arr):
    return arr[::-1]

arr = [1, 2, 3, 4, 5]
print(reverse_slicing(arr))
# Out:
# [5, 4, 3, 2, 1]

# %%
def reverse_built_in(arr):
    arr.reverse()
    return arr
    
arr = [1, 2, 3, 4, 5]
print(reverse_built_in(arr))
# Out:
# [5, 4, 3, 2, 1]

# %%
def reverse_array(arr):
    left, right = 0, len(arr) - 1

    while left < right:
        arr[left], arr[right] = arr[right], arr[left]
        left += 1
        right -= 1

    return arr

arr = [1, 2, 3, 4, 5]
print(reverse_built_in(arr))
# Out:
# [5, 4, 3, 2, 1]

# %%
def reverse_array(arr):
    first = 0
    last = len(arr) - 1

    while first < last:
        temp = arr[first]
        arr[first] = arr[last]
        arr[last] = temp

        first += 1
        last -= 1

    return arr

arr = [1, 2, 3, 4, 5]
print(reverse_array(arr))
# Out:
# [5, 4, 3, 2, 1]
